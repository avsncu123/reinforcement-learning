# %% [markdown]
# <a href="https://colab.research.google.com/github/avsncu123/reinforcement-learning/blob/main/corre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import random
l1 = [random.randint(x,100) for x in range(0,100)]
l2 = [random.randint(x,100) for x in range(0,100)]
plt.scatter(l1,l2)



l3 = [x for x in range(0,12)]
l4 = [x+12 for x in range(0,12)]

l5 = [abs(x-12) for x in range(0,12)]
plt.subplot(1,2,1)
plt.scatter(l3,l4)
plt.subplot(1,2,2)
plt.scatter(l3,l5)




import numpy as np

arr1 = np.array(l1)
arr2 = np.array(l2)

rel = np.corrcoef(arr1,arr2)

print(rel)
plt.plot(rel)



arr1 = np.array(np.random.randint((1000), size=(500)))
arr2 = np.array(np.random.choice((arr1*57), size=(500)))
arr3 = np.array(np.random.choice((-(arr1*75)), size=(500)))
arr4 = np.array(np.random.randint((1000), size=(500)))
plt.figure(figsize=(10,7))
plt.subplot(1,2,1)
plt.scatter(arr1,arr2)
plt.subplot(1,2,2)
plt.scatter(arr1,arr3)

rel = np.corrcoef(arr1,arr2)
print(rel)
plt.plot(rel)

import pandas as pd

df = pd.DataFrame({"A":arr1, "B":arr2, "C":arr3, "D":arr4})

df

corr = df.corr(method='pearson')
corr
# Out:
# <ipython-input-1-3220c35aa3fb>:13: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# [[1.         0.35448856]
#  [0.35448856 1.        ]]
# [[ 1.         -0.01875272]
#  [-0.01875272  1.        ]]
#           A         B         C         D
# A  1.000000 -0.018753 -0.027108  0.003632
# B -0.018753  1.000000 -0.032497 -0.029563
# C -0.027108 -0.032497  1.000000  0.022188
# D  0.003632 -0.029563  0.022188  1.000000
